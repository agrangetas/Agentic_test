# %% [markdown]
# # 🧪 Tests Système Agent Company - Version Complète
#
# Ce notebook permet de tester **tous les composants** du système Agent Company de manière interactive et approfondie.
#
# ## 📋 Plan des tests complets :
#
# ### 🏗️ **1. Tests d'Infrastructure**
# - ✅ Connexions Redis et PostgreSQL
# - ✅ Gestionnaire de cache avancé
# - ✅ Système de logging avec fichiers par agent
# - ✅ Gestionnaire de base de données
# - ✅ Test d'intégration infrastructure complète
#
# ### 🔧 **2. Tests des Outils (Tools)**
# - ✅ Normalisation de noms d'entreprises
# - ✅ Matching et recherche d'entreprises
# - ✅ Extraction d'entités nommées (NER)
# - ✅ Identification de sites web
# - ✅ Validation de cohérence des données
# - ✅ Résolution de conflits automatique
# - ✅ Tests de performance et gestion d'erreurs
#
# ### 🤖 **3. Tests des Agents**
# - ✅ Agent Normalization (détaillé)
# - ✅ Agent Identification (détaillé)
# - ✅ Agent Validation (détaillé)
# - ✅ Tests d'intégration entre agents
# - ✅ Tests de performance sur plusieurs entreprises
# - ✅ Tests de gestion du cache par agent
#
# ### 🎯 **4. Tests de l'Orchestrateur**
# - ✅ Initialisation et configuration
# - ✅ Création de sessions et contextes
# - ✅ Gestion d'erreurs et fallbacks
# - ✅ Métriques et monitoring
# - ✅ Tests de charge (sessions multiples)
#
# ### 🔗 **5. Tests d'Intégration Complète**
# - ✅ Workflow bout en bout
# - ✅ Cohérence des données entre composants
# - ✅ Performance globale du système
# - ✅ Rapports détaillés et visualisations
#
# ---
#
# **🎯 Objectif :** Valider que tous les composants fonctionnent individuellement et ensemble, avec des métriques détaillées et des rapports de performance.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 📦 Imports et Configuration

# %%
import asyncio
import os
import sys
import time
import subprocess
import json
from pathlib import Path
from datetime import datetime

# Ajout du répertoire parent au path
sys.path.append('/app')

# Imports du système
from orchestrator.logging_config import setup_logging, get_agent_logger, get_logging_manager
from orchestrator.cache_manager import CacheManager
from orchestrator.core import OrchestrationEngine, TaskContext
from agents.agent_normalization import AgentNormalization
from agents.agent_identification import AgentIdentification
from agents.agent_validation import AgentValidation

# Configuration pour l'affichage
import warnings
warnings.filterwarnings('ignore')

print("✅ Imports réussis !")
print(f"📅 Démarrage des tests : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# Fonction utilitaire pour exécuter les scripts de test
def run_test_script(script_name):
    """Exécute un script de test et retourne les résultats."""
    try:
        result = subprocess.run(
            ['python', f'/app/test_scripts/{script_name}'],
            capture_output=True,
            text=True,
            timeout=300  # 5 minutes max
        )
        return {
            'success': result.returncode == 0,
            'stdout': result.stdout,
            'stderr': result.stderr,
            'returncode': result.returncode
        }
    except subprocess.TimeoutExpired:
        return {
            'success': False,
            'stdout': '',
            'stderr': 'Timeout: Script execution exceeded 5 minutes',
            'returncode': -1
        }
    except Exception as e:
        return {
            'success': False,
            'stdout': '',
            'stderr': str(e),
            'returncode': -1
        }

# Nouvelle fonction pour scripts avec arguments
def run_test_script_with_args(script_name, *args):
    """Exécute un script de test avec des arguments et retourne les résultats."""
    try:
        cmd = ['python', f'/app/test_scripts/{script_name}'] + list(args)
        result = subprocess.run(
            cmd,
            capture_output=True,
            text=True,
            timeout=300  # 5 minutes max
        )
        return {
            'success': result.returncode == 0,
            'stdout': result.stdout,
            'stderr': result.stderr,
            'returncode': result.returncode
        }
    except subprocess.TimeoutExpired:
        return {
            'success': False,
            'stdout': '',
            'stderr': 'Timeout: Script execution exceeded 5 minutes',
            'returncode': -1
        }
    except Exception as e:
        return {
            'success': False,
            'stdout': '',
            'stderr': str(e),
            'returncode': -1
        }

print("🔧 Fonctions utilitaires configurées")
# Out:
# ✅ Imports réussis !
# 📅 Démarrage des tests : 2025-06-27 15:40:05
# 🔧 Fonctions utilitaires configurées

# %%
#!pip install psycopg2-binary

# %% [markdown]
# # 🏗️ 1. TESTS D'INFRASTRUCTURE
#
# Cette section teste tous les composants d'infrastructure : Redis, PostgreSQL, Cache Manager, Logging, etc.

# %%
print("🏗️ LANCEMENT DES TESTS D'INFRASTRUCTURE")
print("=" * 60)

# Exécution du script de test d'infrastructure
infrastructure_result = run_test_script('test_infrastructure.py')

if infrastructure_result['success']:
    print("✅ TESTS D'INFRASTRUCTURE RÉUSSIS")
    print("\n📊 Sortie détaillée :")
    print(infrastructure_result['stdout'])
else:
    print("❌ ÉCHEC DES TESTS D'INFRASTRUCTURE")
    print("\n🚨 Erreurs :")
    print(infrastructure_result['stderr'])
    if infrastructure_result['stdout']:
        print("\n📊 Sortie partielle :")
        print(infrastructure_result['stdout'])
# Out:
# 🏗️ LANCEMENT DES TESTS D'INFRASTRUCTURE
# ============================================================
# ✅ TESTS D'INFRASTRUCTURE RÉUSSIS
#
# 📊 Sortie détaillée :
# ============================================================
# 🏗️  TESTS INFRASTRUCTURE
# ============================================================
#
# ========================================
# 🔴 Test connexion Redis...
#    📊 Connexion: ✅
#    ⏱️  Ping: 13.1ms
#    💾 Read/Write: ✅
#
# ========================================
# 💾 Test CacheManager...
# 15:31:15 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:31:15 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:15 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:15 | INFO     | orchestrator.cache_manager:invalidate_pattern:289 - Invalidated 1 keys matching pattern: test_cache_key
# 15:31:15 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#    💾 Set: 0.8ms
#    📖 Get: 0.8ms
#    📊 Stats: {'hits': 1, 'misses': 0, 'hit_rate': 1.0, 'sets': 1, 'deletes': 0, 'redis_memory': '1.18M'}
#    🗑️  Invalidation: ✅
#
# ========================================
# 🐘 Test connexion PostgreSQL...
#    📊 Connexion: ✅ (13.3ms)
#    🗃️  Version: PostgreSQL 15.13
#    📋 Tables: 12 trouvées
#    ⏱️  Requête: 1.5ms
#    💾 CRUD: ✅
#
# ========================================
# 🗄️  Test DatabaseManager...
#    📊 Connexion: ✅ (88.1ms)
#    📋 Entreprises: 0
#    ⏱️  Requête: 4.7ms
#    💾 Insert: 3.5ms
#    🔍 Vérification: ✅
#
# ========================================
# 📝 Test système de logging...
# 15:31:15 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:31:15 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:31:15 | INFO     | __main__:test_logging_system:343 - Test log INFO
# 15:31:15 | WARNING  | __main__:test_logging_system:344 - Test log WARNING
# 15:31:15 | ERROR    | __main__:test_logging_system:345 - Test log ERROR
# 15:31:15 | INFO     | __main__:test_logging_system:349 - Test agent log
# 15:31:15 | INFO     | orchestrator.logging_config:log_performance_metric:203 - 📊 test_function_performance: 0.123s
# 15:31:15 | INFO     | orchestrator.logging_config:log_session_event:266 - 🎯 Session e7ccee06-9c28-4fcb-bd5b-454601f6dccf: test_event
#    📝 Logs écrits: ✅
#    ⏱️  Temps logging: 10.2ms
#    📊 Stats: {'logs_directory': 'logs', 'total_log_files': 6, 'total_size_mb': 0.19, 'agents_with_logs': ['identification', 'infrastructure', 'normalization', 'test', 'validation'], 'oldest_log': 'logs/agents/infrastructure_test_2025-06-27.log', 'newest_log': 'logs/app_2025-06-27.log'}
#    🗂️  Fichiers: 0
#    📏 Taille: 0.19 MB
#
# ========================================
# 🔗 Test intégration infrastructure...
# 15:31:15 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:15 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:16 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:31:16 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:31:16 | INFO     | __main__:test_infrastructure_integration:509 - Début test intégration
# 15:31:16 | INFO     | orchestrator.logging_config:log_performance_metric:203 - 📊 infrastructure_integration_test: 0.016017675399780273s
# 15:31:16 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#    🔗 Intégration: ✅
#    ⏱️  Temps total: 16.0ms
#    💾 Cache: ✅
#    🗄️  BDD: ✅
#    📝 Logs: ✅
#
# ============================================================
# 📊 RÉSUMÉ TESTS INFRASTRUCTURE
# ============================================================
# ⏱️  Temps d'exécution total: 0.365s
#    ✅ Redis
#    ✅ Postgresql
#    ✅ Cache Manager
#    ✅ Database Manager
#    ✅ Logging
# 🔗 Intégration globale: ✅

# %% [markdown]
# # 🔧 2. TESTS DES OUTILS (TOOLS)
#
# Cette section teste tous les outils : normalisation, matching, NER, validation, résolution de conflits, etc.

# %%
print("🔧 LANCEMENT DES TESTS DES OUTILS")
print("=" * 60)

# Exécution du script de test des outils
tools_result = run_test_script('test_tools_comprehensive.py')

if tools_result['success']:
    print("✅ TESTS DES OUTILS RÉUSSIS")
    print("\n📊 Sortie détaillée :")
    print(tools_result['stdout'])
else:
    print("❌ ÉCHEC DES TESTS DES OUTILS")
    print("\n🚨 Erreurs :")
    print(tools_result['stderr'])
    if tools_result['stdout']:
        print("\n📊 Sortie partielle :")
        print(tools_result['stdout'])
# Out:
# 🔧 LANCEMENT DES TESTS DES OUTILS
# ============================================================
# ✅ TESTS DES OUTILS RÉUSSIS
#
# 📊 Sortie détaillée :
# ============================================================
# 🔧 TESTS COMPLETS DES OUTILS
# ============================================================
#
# ========================================
# 🔤 Test ToolNormalizeName...
#    📝 LVMH Moët Hennessy Louis Vuitton SE
#       ➡️  LVMH MOËT HENNESSY LOUIS VUITTON
#       🔄 2 variantes
#       🎯 0.80 confiance
#    📝 société test sarl
#       ➡️  SOCIÉTÉ TESAINT
#       🔄 4 variantes
#       🎯 0.90 confiance
#    📝 Apple Inc.
#       ➡️  APPLE INC
#       🔄 2 variantes
#       🎯 0.70 confiance
#    📝 Microsoft Corporation
#       ➡️  MICROSOFT CORPORATION
#       🔄 1 variantes
#       🎯 0.70 confiance
#    📝 Google LLC
#       ➡️  GOOGLE
#       🔄 2 variantes
#       🎯 0.70 confiance
#    📊 Temps moyen: 0.000s
#    🎯 Confiance moyenne: 0.76
#
# ========================================
# 🔍 Test ToolMatchEnterprise...
#    📝 APPLE INC
#       🎯 1 correspondances
#       🏢 SIREN: 552120222
#       📊 0.67 confiance
#    📝 MICROSOFT CORP
#       🎯 1 correspondances
#       🏢 SIREN: 123456789
#       📊 0.50 confiance
#    📝 Unknown Company XYZ
#       🎯 0 correspondances
#       🏢 SIREN: N/A
#       📊 0.00 confiance
#    📊 Temps moyen: 0.000s
#    ✅ Correspondances trouvées: 2/3
#
# ========================================
# 🏷️  Test ToolNERExtraction...
#    📝 Apple Inc. est une entreprise dirigée par Tim Cook...
#       🏢 3 entreprises
#       👤 3 personnes
#       📊 0.76 confiance
#    📝 Microsoft Corporation a été fondée par Bill Gates ...
#       🏢 3 entreprises
#       👤 4 personnes
#       📊 0.77 confiance
#    📝 LVMH est contrôlée par Bernard Arnault via sa hold...
#       🏢 3 entreprises
#       👤 3 personnes
#       📊 0.78 confiance
#    📝 Tesla Inc. développe des véhicules électriques sou...
#       🏢 3 entreprises
#       👤 3 personnes
#       📊 0.78 confiance
#    📊 Temps moyen: 0.001s
#    🏷️  Total entités: 26
#
# ========================================
# 🌐 Test ToolIdentifyWebsite...
#    🏢 Apple Inc
#       🌐 https://www.apple.com
#       📊 found - 0.80
#    🏢 Microsoft Corporation
#       🌐 https://www.microsoft.com
#       📊 found - 0.80
#    🏢 Google LLC
#       🌐 https://www.google.com
#       📊 found - 0.80
#    🏢 Unknown Company XYZ
#       🌐 N/A
#       📊 not_found - 0.00
#    📊 Temps moyen: 0.000s
#    🌐 URLs trouvées: 3/4
#
# ========================================
# ✅ Test ToolValidateConsistency...
#    📊 Test case 1
#       ⚠️  0 conflits
#       ✅ Cohérent: True
#       📊 Score qualité: 0.60
#    📊 Test case 2
#       ⚠️  2 conflits
#       ✅ Cohérent: False
#       📊 Score qualité: 0.10
#    📊 Temps moyen: 0.000s
#
# ========================================
# 🔧 Test ToolResolveConflicts...
#    🔧 2 conflits traités
#    ✅ 2 résolutions
#    📊 Confiance globale: 0.86
#    ⏱️  Temps: 0.000s
#       siren: 123456789 (Source prioritaire (inpi))
#       url: https://www.apple.com (URL HTTPS préférée)
#
# ========================================
# ⚡ Test opérations asynchrones...
#    ⚡ 4 outils testés en parallèle
#    ✅ 4/4 succès
#    ⏱️  Temps total: 0.000s
#
# ========================================
# 🚨 Test gestion d'erreurs...
#    🛡️  4/4 outils gèrent les erreurs
#       ✅ ToolNormalizeName
#       ✅ ToolMatchEnterprise
#       ✅ ToolNERExtraction
#       ✅ ToolIdentifyWebsite
#
# ============================================================
# 📊 RÉSUMÉ DES TESTS OUTILS
# ============================================================
# ⏱️  Temps d'exécution total: 0.004s
# 🔧 Outils testés: 6 principaux + tests transversaux
#    ✅ normalize_name: 0.000s moyen
#    ✅ match_enterprise: 0.000s moyen
#    ✅ ner_extraction: 0.001s moyen
#    ✅ identify_website: 0.000s moyen
#    ✅ validate_consistency: 0.000s moyen
#    ✅ resolve_conflicts: 0.000s moyen
# ⚡ Async: 4/4 outils
# 🛡️  Gestion erreurs: 4/4 outils

# %% [markdown]
# # 🤖 3. TESTS DES AGENTS
#
# Cette section teste tous les agents en détail : Normalization, Identification, Validation, avec tests d'intégration et de performance.

# %%
print("🤖 LANCEMENT DES TESTS DES AGENTS")
print("=" * 60)

# Exécution du script de test des agents
agents_result = run_test_script('test_agents_detailed.py')

if agents_result['success']:
    print("✅ TESTS DES AGENTS RÉUSSIS")
    print("\n📊 Sortie détaillée :")
    print(agents_result['stdout'])
else:
    print("❌ ÉCHEC DES TESTS DES AGENTS")
    print("\n🚨 Erreurs :")
    print(agents_result['stderr'])
    if agents_result['stdout']:
        print("\n📊 Sortie partielle :")
        print(agents_result['stdout'])
# Out:
# 🤖 LANCEMENT DES TESTS DES AGENTS
# ============================================================
# ✅ TESTS DES AGENTS RÉUSSIS
#
# 📊 Sortie détaillée :
# ============================================================
# 🤖 TESTS DÉTAILLÉS DES AGENTS
# ============================================================
#
# ========================================
# 🔄 Test détaillé Agent Normalization...
# 15:31:17 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    📊 Résultat: ❌
#    🎯 Confiance: 0.60
#    ⏱️  Temps: 0.007s
#    📝 Données: ['original_name', 'normalized_name', 'variants', 'matched_entities', 'best_match', 'siren', 'confidence_score', 'named_entities', 'normalization_method']
#    🔍 Erreurs de validation: 1
#    💾 Cache key: normalization:Société Test SARL:851879843089047857...
#    💾 Résultat en cache: Oui
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# ========================================
# 🔍 Test détaillé Agent Identification...
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    📊 Résultat: ✅
#    🎯 Confiance: 0.90
#    ⏱️  Temps: 0.002s
#    🌐 URL trouvée: https://www.lvmh.fr
#    🏢 SIREN: 775670417
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | ERROR    | agents.agent_identification:execute:158 - Identification execution failed
#    📊 Sans normalisation: ❌
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# ========================================
# ✅ Test détaillé Agent Validation...
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    📊 Résultat: ✅
#    🎯 Confiance: 0.35
#    ⏱️  Temps: 0.004s
#    🔍 Conflits détectés: 1
#    🔧 Conflits résolus: 1
#    📊 Score qualité: 0.75
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ⚠️  Avec conflits: ✅
#    🔍 Conflits: 0
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# ========================================
# 🔗 Test d'intégration des agents...
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
#    🔄 Exécution normalization...
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#       ❌ normalization: 0.60
#    🔄 Exécution identification...
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
#       ✅ identification: 0.50
#    🔄 Exécution validation...
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
#       ✅ validation: 0.30
#    🔍 Cohérence SIREN: ✅
#    📊 Données collectées: 3 agents
#    ⏱️  Temps total: 0.015s
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# ========================================
# ⚡ Test de performance des agents...
# 15:31:17 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 15:31:17 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:17 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:31:17 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:17 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:17 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:17 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:17 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
# 15:31:17 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#    📊 Entreprises testées: 5
#    ✅ Succès: 0/5
#    ⏱️  Temps total: 0.062s
#    📊 Temps moyen: 0.006s
#    🎯 Confiance moyenne: 0.00
#
# ============================================================
# 📊 RÉSUMÉ DES TESTS AGENTS
# ============================================================
# ⏱️  Temps d'exécution total: 0.204s
# 🤖 Agents testés: 3 (Normalization, Identification, Validation)
#    ❌ Normalization: 0.60 confiance
#    ✅ Identification: 0.90 confiance
#    ✅ Validation: 0.35 confiance
# 🔗 Intégration: 2/3 agents
# ⚡ Performance: 0.006s/agent moyen

# %% [markdown]
# # 🎯 4. TESTS DE L'ORCHESTRATEUR
#
# Cette section teste l'orchestrateur principal : initialisation, sessions, contextes, gestion d'erreurs, métriques.

# %%
print("🎯 LANCEMENT DES TESTS DE L'ORCHESTRATEUR")
print("=" * 60)

# Exécution du script de test de l'orchestrateur
orchestrator_result = run_test_script('test_orchestrator.py')

if orchestrator_result['success']:
    print("✅ TESTS DE L'ORCHESTRATEUR RÉUSSIS")
    print("\n📊 Sortie détaillée :")
    print(orchestrator_result['stdout'])
else:
    print("❌ ÉCHEC DES TESTS DE L'ORCHESTRATEUR")
    print("\n🚨 Erreurs :")
    print(orchestrator_result['stderr'])
    if orchestrator_result['stdout']:
        print("\n📊 Sortie partielle :")
        print(orchestrator_result['stdout'])
# Out:
# 🎯 LANCEMENT DES TESTS DE L'ORCHESTRATEUR
# ============================================================
# ✅ TESTS DE L'ORCHESTRATEUR RÉUSSIS
#
# 📊 Sortie détaillée :
# ============================================================
# 🎯 TESTS DE L'ORCHESTRATEUR
# ============================================================
# 🎯 Test d'initialisation de l'orchestrateur...
# 15:31:18 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:31:18 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
#    ✅ Orchestrateur initialisé avec succès
# 🎯 Test de création de session...
# 15:31:18 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:31:18 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:18 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
#    ✅ Session créée: 7409b4d9-5676-47fa-84ad-7c93711014f2
#    📊 Statut: initialized
#    ⏱️  Temps: 0.001s
# 🎯 Test de création de contexte...
# 15:31:18 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:18 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
#    ✅ Contexte créé avec succès
#    🏢 Entreprise: Test Company
#    📊 Session: 088416c8-3351-4d56-b44c-a840a2936d18
# 15:31:18 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
# 🎯 Test de gestion d'erreurs...
# 15:31:18 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:31:18 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:18 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
#    ⚠️  Exception capturée:
# 15:31:18 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:18 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
#    ✅ Gestion d'erreur pour config invalide: OK
# 🎯 Test des métriques...
# 15:31:18 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:31:18 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:18 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
# 15:31:18 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:18 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
# 15:31:18 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:18 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
#    ✅ Sessions exécutées: 3
#    ✅ Sessions réussies: 3
#    ⏱️  Temps total: 0.006s
#    📊 Temps moyen par session: 0.002s
#
# ============================================================
# 📊 RÉSUMÉ DES TESTS ORCHESTRATEUR
# ============================================================
# ⏱️  Temps d'exécution total: 0.084s
# ✅ Tests réussis: 5
# 🎯 Orchestrateur: Pleinement fonctionnel

# %% [markdown]
# # 🔗 5. TESTS D'INTÉGRATION COMPLÈTE
#
# Cette section teste le workflow complet bout en bout avec le script de test système existant.

# %%
print("🔗 LANCEMENT DES TESTS D'INTÉGRATION COMPLÈTE")
print("=" * 60)

# Exécution du script de test système complet
integration_result = run_test_script('test_system_simple.py')

if integration_result['success']:
    print("✅ TESTS D'INTÉGRATION RÉUSSIS")
    print("\n📊 Sortie détaillée :")
    print(integration_result['stdout'])
else:
    print("❌ ÉCHEC DES TESTS D'INTÉGRATION")
    print("\n🚨 Erreurs :")
    print(integration_result['stderr'])
    if integration_result['stdout']:
        print("\n📊 Sortie partielle :")
        print(integration_result['stdout'])
# Out:
# 🔗 LANCEMENT DES TESTS D'INTÉGRATION COMPLÈTE
# ============================================================
# ✅ TESTS D'INTÉGRATION RÉUSSIS
#
# 📊 Sortie détaillée :
# ============================================================
# 🧠 TEST DU SYSTÈME AGENT COMPANY INTELLIGENCE
# ============================================================
# 🔧 Test du système de logging...
# 15:31:20 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:31:20 | INFO     | orchestrator.logging_config:setup_logging:372 - Logging system configured successfully
# 15:31:20 | INFO     | __main__:test_logging:36 - Test du système de logging depuis script
# 15:31:20 | INFO     | __main__:test_logging:43 - Test de log spécifique à un agent
#    📊 Statistiques: 6 fichiers, 0.25 MB
# 💾 Test du cache Redis...
# 15:31:20 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:31:20 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
#    📊 Statistiques: 1 hits, 0 misses
# 🤖 Test des agents...
# 15:31:20 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:20 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:20 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:31:20 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:31:20 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:31:20 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    🔄 Normalization: ❌ (confiance: 0.60)
# 15:31:20 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:20 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:20 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:31:20 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    🔍 Identification: ✅ (confiance: 0.50)
# 15:31:20 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:31:20 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:31:20 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:31:20 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: ✅ (confiance: 0.30)
# 🎯 Test de l'orchestrateur...
# 15:31:20 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:31:20 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:31:20 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
#    🚀 Session: initialized (0.001s)
#
# ============================================================
# 📊 RÉSUMÉ DES TESTS
# ============================================================
# ⏱️  Temps d'exécution total: 0.107s
#
# 🤖 Agents testés:
#    ❌ normalization: 0.60 confiance
#    ✅ identification: 0.50 confiance
#    ✅ validation: 0.30 confiance
#
# 🎯 Orchestrateur: initialized
#
# 📊 Statistiques finales:
#    📝 Logs: 6 fichiers
#    💾 Cache: 50.0% hit rate
# 15:31:20 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 🎉 Tous les tests sont terminés avec succès !

# %% [markdown]
# # 📊 6. RAPPORT DE SYNTHÈSE
#
# Cette section génère un rapport de synthèse complet de tous les tests.

# %%
print("📊 GÉNÉRATION DU RAPPORT DE SYNTHÈSE")
print("=" * 60)

# Collecte des résultats de tous les tests
test_results = {
    'infrastructure': infrastructure_result,
    'tools': tools_result,
    'agents': agents_result,
    'orchestrator': orchestrator_result,
    'integration': integration_result
}

# Calcul des statistiques globales
total_tests = len(test_results)
successful_tests = sum(1 for result in test_results.values() if result['success'])
failed_tests = total_tests - successful_tests

print(f"📈 STATISTIQUES GLOBALES")
print(f"   Total des modules testés : {total_tests}")
print(f"   ✅ Modules réussis : {successful_tests}")
print(f"   ❌ Modules échoués : {failed_tests}")
print(f"   📊 Taux de réussite : {(successful_tests/total_tests)*100:.1f}%")

print(f"\n🔍 DÉTAIL PAR MODULE :")
for module_name, result in test_results.items():
    status = "✅" if result['success'] else "❌"
    print(f"   {status} {module_name.upper()}")
    if not result['success'] and result['stderr']:
        print(f"      🚨 Erreur : {result['stderr'][:100]}...")

print(f"\n⏱️  TEMPS D'EXÉCUTION :")
print(f"   Fin des tests : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# Recommandations
print(f"\n💡 RECOMMANDATIONS :")
if successful_tests == total_tests:
    print("   🎉 Tous les tests sont réussis ! Le système est opérationnel.")
    print("   🚀 Vous pouvez procéder aux tests en production.")
elif successful_tests >= total_tests * 0.8:
    print("   ⚠️  La plupart des tests sont réussis, mais attention aux échecs.")
    print("   🔧 Corrigez les modules échoués avant la mise en production.")
else:
    print("   🚨 Plusieurs modules ont échoué. Investigation nécessaire.")
    print("   🛠️  Vérifiez la configuration et les dépendances.")

print(f"\n📝 LOGS DÉTAILLÉS :")
print(f"   Les logs détaillés sont disponibles dans le dossier /app/logs/")
print(f"   Consultez les fichiers par agent pour plus de détails.")

print("\n" + "=" * 60)
print("🏁 FIN DES TESTS COMPLETS")
print("=" * 60)
# Out:
# 📊 GÉNÉRATION DU RAPPORT DE SYNTHÈSE
# ============================================================
# 📈 STATISTIQUES GLOBALES
#    Total des modules testés : 5
#    ✅ Modules réussis : 5
#    ❌ Modules échoués : 0
#    📊 Taux de réussite : 100.0%
#
# 🔍 DÉTAIL PAR MODULE :
#    ✅ INFRASTRUCTURE
#    ✅ TOOLS
#    ✅ AGENTS
#    ✅ ORCHESTRATOR
#    ✅ INTEGRATION
#
# ⏱️  TEMPS D'EXÉCUTION :
#    Fin des tests : 2025-06-27 15:31:20
#
# 💡 RECOMMANDATIONS :
#    🎉 Tous les tests sont réussis ! Le système est opérationnel.
#    🚀 Vous pouvez procéder aux tests en production.
#
# 📝 LOGS DÉTAILLÉS :
#    Les logs détaillés sont disponibles dans le dossier /app/logs/
#    Consultez les fichiers par agent pour plus de détails.
#
# ============================================================
# 🏁 FIN DES TESTS COMPLETS
# ============================================================

# %% [markdown]
# # 🎮 7. TESTS INTERACTIFS PERSONNALISÉS
#
# Cette section permet d'exécuter des tests personnalisés sur des entreprises spécifiques.

# %%
# Tests interactifs - Modifiez les paramètres selon vos besoins

print("🎮 TESTS INTERACTIFS PERSONNALISÉS")
print("=" * 60)

# 1. Test sur une entreprise spécifique
print("\n1️⃣ Test sur une entreprise spécifique:")
company_to_test = "Apple Inc"  # Modifiez ici le nom de l'entreprise
detailed_mode = True  # True pour plus de détails

print(f"🏢 Test de : {company_to_test}")
args = ['single', company_to_test]
if detailed_mode:
    args.append('detailed')
single_result = run_test_script_with_args('test_interactive.py', *args)

if single_result['success']:
    print("✅ Test réussi")
    print(single_result['stdout'])
else:
    print("❌ Test échoué")
    print(single_result['stderr'])

print("\n" + "-" * 40)
# Out:
# 🎮 TESTS INTERACTIFS PERSONNALISÉS
# ============================================================
#
# 1️⃣ Test sur une entreprise spécifique:
# 🏢 Test de : Apple Inc
# ✅ Test réussi
# 🏢 Test complet pour : Apple Inc
# --------------------------------------------------
# 15:40:10 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:10 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:10 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:10 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:10 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:10 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:10 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:10 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:10 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:10 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:10 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:10 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:10 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.60 confiance (0.015s)
#       📊 Données: {
#   "original_name": "Apple Inc",
#   "normalized_name": "APPLE",
#   "variants": [
#     "apple inc",
#     "Apple Inc",
#     "APPLE",
#     "APPLE INC"
#   ],
#   "matched_entities": [
#     {
#       "name": "apple i...
# 🔄 Exécution agent Identification...
# 15:40:10 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:10 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:10 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.50 confiance (0.005s)
#       📊 Données: {
#   "siren": "123456789",
#   "url": "https://www.apple.com",
#   "normalized_name": "APPLE",
#   "original_name": "Apple Inc",
#   "confidence_score": 0.5,
#   "identification_method": "from_normalization",
#   ...
# 🔄 Exécution agent Validation...
# 15:40:10 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:10 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:10 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.30 confiance (0.008s)
#       📊 Données: {
#   "conflicts_detected": [
#     {
#       "type": "siren_mismatch",
#       "field": "siren",
#       "value1": "123456789",
#       "source1": "normalization",
#       "value2": "123456789",
#       "source2": "...
# 15:40:10 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Apple Inc:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.40
#    ⏱️  Temps total: 0.028s
#
# 📋 Résultat final: {
#   "company": "Apple Inc",
#   "results": {
#     "normalization": {
#       "success": false,
#       "confidence": 0.6,
#       "execution_time": 0.015146970748901367,
#       "data_keys": [
#         "original_name",
#         "normalized_name",
#         "variants",
#         "matched_entities",
#         "best_match",
#         "siren",
#         "confidence_score",
#         "named_entities",
#         "normalization_method"
#       ],
#       "errors": [
#         "Missing required field: enterprise_name"
#       ]
#     },
#     "identification": {
#       "success": true,
#       "confidence": 0.5,
#       "execution_time": 0.004720926284790039,
#       "data_keys": [
#         "siren",
#         "url",
#         "normalized_name",
#         "original_name",
#         "confidence_score",
#         "identification_method",
#         "url_method",
#         "verified"
#       ],
#       "errors": []
#     },
#     "validation": {
#       "success": true,
#       "confidence": 0.30000000000000004,
#       "execution_time": 0.007937908172607422,
#       "data_keys": [
#         "conflicts_detected",
#         "conflicts_resolved",
#         "consistency_score",
#         "data_quality_score",
#         "linked_entities",
#         "validation_summary",
#         "recommendations"
#       ],
#       "errors": []
#     }
#   },
#   "summary": {
#     "successful_agents": 2,
#     "total_agents": 3,
#     "average_confidence": 0.4,
#     "total_time": 0.027805805206298828
#   }
# }
#
#
# ----------------------------------------

# %%
# 2. Test sur plusieurs entreprises
print("2️⃣ Test sur plusieurs entreprises:")
companies_to_test = ["Microsoft Corp", "Google LLC", "Tesla Inc"]  # Modifiez cette liste
detailed_multi = False  # True pour plus de détails

companies_str = ",".join(companies_to_test)
print(f"🏢 Test de : {companies_to_test}")

args = ['multiple', companies_str]
if detailed_multi:
    args.append('detailed')
multi_result = run_test_script_with_args('test_interactive.py', *args)

if multi_result['success']:
    print("✅ Test réussi")
    print(multi_result['stdout'])
else:
    print("❌ Test échoué")
    print(multi_result['stderr'])

print("\n" + "-" * 40)
# Out:
# 2️⃣ Test sur plusieurs entreprises:
# 🏢 Test de : ['Microsoft Corp', 'Google LLC', 'Tesla Inc']
# ✅ Test réussi
# 🏢 Test sur 3 entreprises
# ============================================================
#
# [1/3] Traitement de Microsoft Corp...
# 🏢 Test complet pour : Microsoft Corp
# --------------------------------------------------
# 15:40:24 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:24 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:24 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:24 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:24 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:24 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:24 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.88 confiance (0.017s)
# 🔄 Exécution agent Identification...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.90 confiance (0.006s)
# 🔄 Exécution agent Validation...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.35 confiance (0.009s)
# 15:40:24 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Microsoft Corp:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.62
#    ⏱️  Temps total: 0.032s
#
# [2/3] Traitement de Google LLC...
# 🏢 Test complet pour : Google LLC
# --------------------------------------------------
# 15:40:24 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:24 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:24 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:24 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:24 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:24 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.90 confiance (0.007s)
# 🔄 Exécution agent Identification...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.90 confiance (0.002s)
# 🔄 Exécution agent Validation...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.35 confiance (0.004s)
# 15:40:24 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Google LLC:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.62
#    ⏱️  Temps total: 0.013s
#
# [3/3] Traitement de Tesla Inc...
# 🏢 Test complet pour : Tesla Inc
# --------------------------------------------------
# 15:40:24 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:24 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:24 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:24 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:24 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:24 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:24 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.60 confiance (0.007s)
# 🔄 Exécution agent Identification...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.50 confiance (0.002s)
# 🔄 Exécution agent Validation...
# 15:40:24 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:24 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:24 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.30 confiance (0.003s)
# 15:40:24 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Tesla Inc:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.40
#    ⏱️  Temps total: 0.012s
#
# ============================================================
# 📊 STATISTIQUES GLOBALES
#    🏢 Entreprises testées: 3
#    ✅ Entreprises avec succès: 3
#    🎯 Confiance moyenne globale: 0.55
#    ⏱️  Temps moyen par entreprise: 0.019s
#    ⏱️  Temps total: 0.218s
#
# 📋 Résultat final: {
#   "total_companies": 3,
#   "successful_companies": 3,
#   "average_confidence": 0.5499999999999999,
#   "average_time_per_company": 0.019179503122965496,
#   "total_time": 0.2177271842956543
# }
#
#
# ----------------------------------------

# %%
# 3. Test workflow orchestrateur (CORRIGÉ)
print("3️⃣ Test workflow complet via orchestrateur:")
orchestrator_company = "Amazon Inc"  # Modifiez ici

print(f"🎯 Test orchestrateur pour : {orchestrator_company}")
orchestrator_result = run_test_script_with_args('test_interactive.py', 'orchestrator', orchestrator_company)

if orchestrator_result['success']:
    print("✅ Test réussi")
    print(orchestrator_result['stdout'])
else:
    print("❌ Test échoué")
    print(orchestrator_result['stderr'])

print("\n" + "-" * 40)
# Out:
# 3️⃣ Test workflow complet via orchestrateur:
# 🎯 Test orchestrateur pour : Amazon Inc
# ✅ Test réussi
# 🎯 Test workflow orchestrateur pour : Amazon Inc
# --------------------------------------------------
# 15:40:35 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:35 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:40:35 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:40:35 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
# ✅ Workflow terminé en 0.001s
# 📊 Session ID: 745848b9-5b2c-4fa7-b32b-c62b3bb10e7c
# 📊 Statut: initialized
#
# 📋 Résultat final: {
#   "success": true,
#   "company": "Amazon Inc",
#   "execution_time": 0.0010695457458496094,
#   "result": {
#     "session_id": "745848b9-5b2c-4fa7-b32b-c62b3bb10e7c",
#     "enterprise_name": "Amazon Inc",
#     "status": "initialized",
#     "message": "Session created successfully",
#     "execution_time": 0.0006296634674072266
#   }
# }
#
#
# ----------------------------------------

# %%
# 3. Test workflow orchestrateur
print("3️⃣ Test workflow complet via orchestrateur:")
orchestrator_company = "Amazon Inc"  # Modifiez ici

print(f"🎯 Test orchestrateur pour : {orchestrator_company}")
orchestrator_result = run_test_script_with_args('test_interactive.py', 'orchestrator', orchestrator_company)

if orchestrator_result['success']:
    print("✅ Test réussi")
    print(orchestrator_result['stdout'])
else:
    print("❌ Test échoué")
    print(orchestrator_result['stderr'])

print("\n" + "-" * 40)
# Out:
# 3️⃣ Test workflow complet via orchestrateur:
# 🎯 Test orchestrateur pour : Amazon Inc
# ✅ Test réussi
# 🎯 Test workflow orchestrateur pour : Amazon Inc
# --------------------------------------------------
# 15:40:41 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:41 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:40:41 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:40:41 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
# ✅ Workflow terminé en 0.001s
# 📊 Session ID: 4f1916e6-f201-4082-a173-34592dd866d3
# 📊 Statut: initialized
#
# 📋 Résultat final: {
#   "success": true,
#   "company": "Amazon Inc",
#   "execution_time": 0.0011224746704101562,
#   "result": {
#     "session_id": "4f1916e6-f201-4082-a173-34592dd866d3",
#     "enterprise_name": "Amazon Inc",
#     "status": "initialized",
#     "message": "Session created successfully",
#     "execution_time": 0.0006096363067626953
#   }
# }
#
#
# ----------------------------------------

# %%
# 🎮 TESTS INTERACTIFS PERSONNALISÉS (VERSION CORRIGÉE)

print("🎮 TESTS INTERACTIFS PERSONNALISÉS (VERSION CORRIGÉE)")
print("=" * 60)

# 1. Test sur une entreprise spécifique
print("\n1️⃣ Test sur une entreprise spécifique:")
company_to_test = "Apple Inc"  # Modifiez ici le nom de l'entreprise
detailed_mode = True  # True pour plus de détails

print(f"🏢 Test de : {company_to_test}")
args = ['single', company_to_test]
if detailed_mode:
    args.append('detailed')
single_result = run_test_script_with_args('test_interactive.py', *args)

if single_result['success']:
    print("✅ Test réussi")
    print(single_result['stdout'])
else:
    print("❌ Test échoué")
    print(single_result['stderr'])

print("\n" + "-" * 40)

# 2. Test sur plusieurs entreprises
print("2️⃣ Test sur plusieurs entreprises:")
companies_to_test = ["Microsoft Corp", "Google LLC", "Tesla Inc"]  # Modifiez cette liste
detailed_multi = False  # True pour plus de détails

companies_str = ",".join(companies_to_test)
print(f"🏢 Test de : {companies_to_test}")

args = ['multiple', companies_str]
if detailed_multi:
    args.append('detailed')
multi_result = run_test_script_with_args('test_interactive.py', *args)

if multi_result['success']:
    print("✅ Test réussi")
    print(multi_result['stdout'])
else:
    print("❌ Test échoué")
    print(multi_result['stderr'])

print("\n" + "-" * 40)

# 3. Test workflow orchestrateur
print("3️⃣ Test workflow complet via orchestrateur:")
orchestrator_company = "Amazon Inc"  # Modifiez ici

print(f"🎯 Test orchestrateur pour : {orchestrator_company}")
orchestrator_result = run_test_script_with_args('test_interactive.py', 'orchestrator', orchestrator_company)

if orchestrator_result['success']:
    print("✅ Test réussi")
    print(orchestrator_result['stdout'])
else:
    print("❌ Test échoué")
    print(orchestrator_result['stderr'])

print("\n" + "-" * 40)

# 4. Test performance cache
print("4️⃣ Test de performance du cache:")
cache_result = run_test_script_with_args('test_interactive.py', 'cache')

if cache_result['success']:
    print("✅ Test réussi")
    print(cache_result['stdout'])
else:
    print("❌ Test échoué")
    print(cache_result['stderr'])

print("\n" + "=" * 60)
print("🎮 FIN DES TESTS INTERACTIFS")
print("=" * 60)
# Out:
# 🎮 TESTS INTERACTIFS PERSONNALISÉS (VERSION CORRIGÉE)
# ============================================================
#
# 1️⃣ Test sur une entreprise spécifique:
# 🏢 Test de : Apple Inc
# ✅ Test réussi
# 🏢 Test complet pour : Apple Inc
# --------------------------------------------------
# 15:40:46 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:46 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:46 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:46 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:46 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:46 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:46 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:46 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:46 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:46 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:46 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:46 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:46 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.60 confiance (0.014s)
#       📊 Données: {
#   "original_name": "Apple Inc",
#   "normalized_name": "APPLE",
#   "variants": [
#     "APPLE INC",
#     "Apple Inc",
#     "APPLE",
#     "apple inc"
#   ],
#   "matched_entities": [
#     {
#       "name": "APPLE I...
# 🔄 Exécution agent Identification...
# 15:40:46 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:46 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:46 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.50 confiance (0.005s)
#       📊 Données: {
#   "siren": "123456789",
#   "url": "https://www.apple.com",
#   "normalized_name": "APPLE",
#   "original_name": "Apple Inc",
#   "confidence_score": 0.5,
#   "identification_method": "from_normalization",
#   ...
# 🔄 Exécution agent Validation...
# 15:40:46 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:46 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:46 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.30 confiance (0.008s)
#       📊 Données: {
#   "conflicts_detected": [
#     {
#       "type": "siren_mismatch",
#       "field": "siren",
#       "value1": "123456789",
#       "source1": "normalization",
#       "value2": "123456789",
#       "source2": "...
# 15:40:46 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Apple Inc:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.40
#    ⏱️  Temps total: 0.026s
#
# 📋 Résultat final: {
#   "company": "Apple Inc",
#   "results": {
#     "normalization": {
#       "success": false,
#       "confidence": 0.6,
#       "execution_time": 0.013700723648071289,
#       "data_keys": [
#         "original_name",
#         "normalized_name",
#         "variants",
#         "matched_entities",
#         "best_match",
#         "siren",
#         "confidence_score",
#         "named_entities",
#         "normalization_method"
#       ],
#       "errors": [
#         "Missing required field: enterprise_name"
#       ]
#     },
#     "identification": {
#       "success": true,
#       "confidence": 0.5,
#       "execution_time": 0.004871845245361328,
#       "data_keys": [
#         "siren",
#         "url",
#         "normalized_name",
#         "original_name",
#         "confidence_score",
#         "identification_method",
#         "url_method",
#         "verified"
#       ],
#       "errors": []
#     },
#     "validation": {
#       "success": true,
#       "confidence": 0.30000000000000004,
#       "execution_time": 0.007880687713623047,
#       "data_keys": [
#         "conflicts_detected",
#         "conflicts_resolved",
#         "consistency_score",
#         "data_quality_score",
#         "linked_entities",
#         "validation_summary",
#         "recommendations"
#       ],
#       "errors": []
#     }
#   },
#   "summary": {
#     "successful_agents": 2,
#     "total_agents": 3,
#     "average_confidence": 0.4,
#     "total_time": 0.026453256607055664
#   }
# }
#
#
# ----------------------------------------
# 2️⃣ Test sur plusieurs entreprises:
# 🏢 Test de : ['Microsoft Corp', 'Google LLC', 'Tesla Inc']
# ✅ Test réussi
# 🏢 Test sur 3 entreprises
# ============================================================
#
# [1/3] Traitement de Microsoft Corp...
# 🏢 Test complet pour : Microsoft Corp
# --------------------------------------------------
# 15:40:47 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:47 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:47 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:47 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:47 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:47 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:47 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.88 confiance (0.016s)
# 🔄 Exécution agent Identification...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.90 confiance (0.006s)
# 🔄 Exécution agent Validation...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.35 confiance (0.009s)
# 15:40:47 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Microsoft Corp:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.62
#    ⏱️  Temps total: 0.032s
#
# [2/3] Traitement de Google LLC...
# 🏢 Test complet pour : Google LLC
# --------------------------------------------------
# 15:40:47 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:47 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:47 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:47 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:47 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:47 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.90 confiance (0.007s)
# 🔄 Exécution agent Identification...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.90 confiance (0.002s)
# 🔄 Exécution agent Validation...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.35 confiance (0.003s)
# 15:40:47 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Google LLC:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.62
#    ⏱️  Temps total: 0.012s
#
# [3/3] Traitement de Tesla Inc...
# 🏢 Test complet pour : Tesla Inc
# --------------------------------------------------
# 15:40:47 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:47 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:47 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:47 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:47 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:47 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:47 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.60 confiance (0.007s)
# 🔄 Exécution agent Identification...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.50 confiance (0.002s)
# 🔄 Exécution agent Validation...
# 15:40:47 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:47 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:47 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.30 confiance (0.004s)
# 15:40:47 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Tesla Inc:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.40
#    ⏱️  Temps total: 0.013s
#
# ============================================================
# 📊 STATISTIQUES GLOBALES
#    🏢 Entreprises testées: 3
#    ✅ Entreprises avec succès: 3
#    🎯 Confiance moyenne globale: 0.55
#    ⏱️  Temps moyen par entreprise: 0.019s
#    ⏱️  Temps total: 0.195s
#
# 📋 Résultat final: {
#   "total_companies": 3,
#   "successful_companies": 3,
#   "average_confidence": 0.5499999999999999,
#   "average_time_per_company": 0.01886145273844401,
#   "total_time": 0.19491028785705566
# }
#
#
# ----------------------------------------
# 3️⃣ Test workflow complet via orchestrateur:
# 🎯 Test orchestrateur pour : Amazon Inc
# ✅ Test réussi
# 🎯 Test workflow orchestrateur pour : Amazon Inc
# --------------------------------------------------
# 15:40:48 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:48 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:40:48 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:40:48 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
# ✅ Workflow terminé en 0.001s
# 📊 Session ID: b4c0656f-03bf-437a-88c4-9acfe1b40b34
# 📊 Statut: initialized
#
# 📋 Résultat final: {
#   "success": true,
#   "company": "Amazon Inc",
#   "execution_time": 0.0013995170593261719,
#   "result": {
#     "session_id": "b4c0656f-03bf-437a-88c4-9acfe1b40b34",
#     "enterprise_name": "Amazon Inc",
#     "status": "initialized",
#     "message": "Session created successfully",
#     "execution_time": 0.0007283687591552734
#   }
# }
#
#
# ----------------------------------------
# 4️⃣ Test de performance du cache:
# ❌ Test échoué
# 2025-06-27 15:40:49.431 | INFO     | orchestrator.model_router:__init__:19 - ModelRouter initialized
# 2025-06-27 15:40:49.432 | INFO     | orchestrator.queue_manager:__init__:19 - SimpleQueueManager initialized
# Traceback (most recent call last):
#   File "/app/test_scripts/test_interactive.py", line 317, in <module>
#     main()
#     ^^^^^^
#   File "/app/test_scripts/test_interactive.py", line 308, in main
#     result = asyncio.run(test_cache_performance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/base_events.py", line 654, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/app/test_scripts/test_interactive.py", line 243, in test_cache_performance
#     await cache_manager.invalidate_category("performance")
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'CacheManager' object has no attribute 'invalidate_category'. Did you mean: 'invalidate_pattern'?
#
#
# ============================================================
# 🎮 FIN DES TESTS INTERACTIFS
# ============================================================

# %%
## ✅ **CORRECTION APPLIQUÉE**

**Problème résolu :** Les tests interactifs échouaient car la fonction `run_test_script()` ne pouvait pas gérer les arguments de ligne de commande.

**Solution :** 
- ✅ Ajout de la fonction `run_test_script_with_args()` qui accepte des arguments
- ✅ Modification des appels pour utiliser la nouvelle fonction
- ✅ Tests validés et fonctionnels

**Utilisation :**
```python
# Ancien (ne fonctionne pas avec arguments)
run_test_script('test_interactive.py single "Apple Inc" detailed')

# Nouveau (fonctionne correctement)
run_test_script_with_args('test_interactive.py', 'single', 'Apple Inc', 'detailed')
```

**⚠️ Note :** Exécutez la cellule ci-dessus au lieu des cellules 18-21 qui contiennent l'ancien code.

# %%
# TESTS INTERACTIFS CORRIGÉS - Exécutez cette cellule

print("🎮 TESTS INTERACTIFS PERSONNALISÉS (VERSION CORRIGÉE)")
print("=" * 60)

# 1. Test sur une entreprise spécifique
print("\n1️⃣ Test sur une entreprise spécifique:")
company_to_test = "Apple Inc"  # Modifiez ici le nom de l'entreprise
detailed_mode = True  # True pour plus de détails

print(f"🏢 Test de : {company_to_test}")
args = ['single', company_to_test]
if detailed_mode:
    args.append('detailed')
single_result = run_test_script_with_args('test_interactive.py', *args)

if single_result['success']:
    print("✅ Test réussi")
    print(single_result['stdout'])
else:
    print("❌ Test échoué")
    print(single_result['stderr'])

print("\n" + "-" * 40)

# 2. Test sur plusieurs entreprises
print("2️⃣ Test sur plusieurs entreprises:")
companies_to_test = ["Microsoft Corp", "Google LLC", "Tesla Inc"]  # Modifiez cette liste
detailed_multi = False  # True pour plus de détails

companies_str = ",".join(companies_to_test)
print(f"🏢 Test de : {companies_to_test}")

args = ['multiple', companies_str]
if detailed_multi:
    args.append('detailed')
multi_result = run_test_script_with_args('test_interactive.py', *args)

if multi_result['success']:
    print("✅ Test réussi")
    print(multi_result['stdout'])
else:
    print("❌ Test échoué")
    print(multi_result['stderr'])

print("\n" + "-" * 40)

# 3. Test workflow orchestrateur
print("3️⃣ Test workflow complet via orchestrateur:")
orchestrator_company = "Amazon Inc"  # Modifiez ici

print(f"🎯 Test orchestrateur pour : {orchestrator_company}")
orchestrator_result = run_test_script_with_args('test_interactive.py', 'orchestrator', orchestrator_company)

if orchestrator_result['success']:
    print("✅ Test réussi")
    print(orchestrator_result['stdout'])
else:
    print("❌ Test échoué")
    print(orchestrator_result['stderr'])

print("\n" + "-" * 40)

# 4. Test performance cache
print("4️⃣ Test de performance du cache:")
cache_result = run_test_script_with_args('test_interactive.py', 'cache')

if cache_result['success']:
    print("✅ Test réussi")
    print(cache_result['stdout'])
else:
    print("❌ Test échoué")
    print(cache_result['stderr'])

print("\n" + "=" * 60)
print("🎮 FIN DES TESTS INTERACTIFS")
print("=" * 60)
# Out:
# 🎮 TESTS INTERACTIFS PERSONNALISÉS (VERSION CORRIGÉE)
# ============================================================
#
# 1️⃣ Test sur une entreprise spécifique:
# 🏢 Test de : Apple Inc
# ✅ Test réussi
# 🏢 Test complet pour : Apple Inc
# --------------------------------------------------
# 15:40:55 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:55 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:55 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:55 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:55 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:55 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:55 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:55 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:55 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:55 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:55 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:55 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:55 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.60 confiance (0.015s)
#       📊 Données: {
#   "original_name": "Apple Inc",
#   "normalized_name": "APPLE",
#   "variants": [
#     "APPLE",
#     "apple inc",
#     "APPLE INC",
#     "Apple Inc"
#   ],
#   "matched_entities": [
#     {
#       "name": "APPLE (...
# 🔄 Exécution agent Identification...
# 15:40:55 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:55 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:55 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.50 confiance (0.005s)
#       📊 Données: {
#   "siren": "123456789",
#   "url": "https://www.apple.com",
#   "normalized_name": "APPLE",
#   "original_name": "Apple Inc",
#   "confidence_score": 0.5,
#   "identification_method": "from_normalization",
#   ...
# 🔄 Exécution agent Validation...
# 15:40:55 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:55 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:55 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.30 confiance (0.008s)
#       📊 Données: {
#   "conflicts_detected": [
#     {
#       "type": "siren_mismatch",
#       "field": "siren",
#       "value1": "123456789",
#       "source1": "normalization",
#       "value2": "123456789",
#       "source2": "...
# 15:40:55 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Apple Inc:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.40
#    ⏱️  Temps total: 0.029s
#
# 📋 Résultat final: {
#   "company": "Apple Inc",
#   "results": {
#     "normalization": {
#       "success": false,
#       "confidence": 0.6,
#       "execution_time": 0.015310049057006836,
#       "data_keys": [
#         "original_name",
#         "normalized_name",
#         "variants",
#         "matched_entities",
#         "best_match",
#         "siren",
#         "confidence_score",
#         "named_entities",
#         "normalization_method"
#       ],
#       "errors": [
#         "Missing required field: enterprise_name"
#       ]
#     },
#     "identification": {
#       "success": true,
#       "confidence": 0.5,
#       "execution_time": 0.005148172378540039,
#       "data_keys": [
#         "siren",
#         "url",
#         "normalized_name",
#         "original_name",
#         "confidence_score",
#         "identification_method",
#         "url_method",
#         "verified"
#       ],
#       "errors": []
#     },
#     "validation": {
#       "success": true,
#       "confidence": 0.30000000000000004,
#       "execution_time": 0.008372068405151367,
#       "data_keys": [
#         "conflicts_detected",
#         "conflicts_resolved",
#         "consistency_score",
#         "data_quality_score",
#         "linked_entities",
#         "validation_summary",
#         "recommendations"
#       ],
#       "errors": []
#     }
#   },
#   "summary": {
#     "successful_agents": 2,
#     "total_agents": 3,
#     "average_confidence": 0.4,
#     "total_time": 0.028830289840698242
#   }
# }
#
#
# ----------------------------------------
# 2️⃣ Test sur plusieurs entreprises:
# 🏢 Test de : ['Microsoft Corp', 'Google LLC', 'Tesla Inc']
# ✅ Test réussi
# 🏢 Test sur 3 entreprises
# ============================================================
#
# [1/3] Traitement de Microsoft Corp...
# 🏢 Test complet pour : Microsoft Corp
# --------------------------------------------------
# 15:40:56 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:56 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:56 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:56 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:56 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:56 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:56 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.88 confiance (0.016s)
# 🔄 Exécution agent Identification...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.90 confiance (0.005s)
# 🔄 Exécution agent Validation...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.35 confiance (0.008s)
# 15:40:56 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Microsoft Corp:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.62
#    ⏱️  Temps total: 0.030s
#
# [2/3] Traitement de Google LLC...
# 🏢 Test complet pour : Google LLC
# --------------------------------------------------
# 15:40:56 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:56 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:56 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:56 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:56 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:56 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.90 confiance (0.007s)
# 🔄 Exécution agent Identification...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.90 confiance (0.002s)
# 🔄 Exécution agent Validation...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.35 confiance (0.003s)
# 15:40:56 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Google LLC:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.62
#    ⏱️  Temps total: 0.012s
#
# [3/3] Traitement de Tesla Inc...
# 🏢 Test complet pour : Tesla Inc
# --------------------------------------------------
# 15:40:56 | INFO     | orchestrator.cache_manager:__init__:37 - CacheManager initialized
# 15:40:56 | INFO     | orchestrator.cache_manager:connect:86 - Connected to Redis successfully
# 15:40:56 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:56 | INFO     | orchestrator.logging_config:setup_logging:298 - Logging system reconfigured
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 15:40:56 | INFO     | agents.base:__init__:62 - Agent initialized
# 🔄 Exécution agent Normalization...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | WARNING  | agents.agent_normalization:execute:141 - Data validation errors found
# 15:40:56 | INFO     | agents.agent_normalization:execute:149 - Normalization execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
# 15:40:56 | WARNING  | agents.base:post_execute:114 - Agent execution had errors
#    ❌ Normalization: 0.60 confiance (0.007s)
# 🔄 Exécution agent Identification...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | INFO     | agents.agent_identification:execute:126 - Identification execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Identification: 0.50 confiance (0.002s)
# 🔄 Exécution agent Validation...
# 15:40:56 | INFO     | agents.base:pre_execute:82 - Starting agent execution
# 15:40:56 | INFO     | agents.agent_validation:execute:137 - Validation execution successful
# 15:40:56 | INFO     | agents.base:post_execute:101 - Agent execution completed
#    ✅ Validation: 0.30 confiance (0.003s)
# 15:40:56 | INFO     | orchestrator.cache_manager:disconnect:106 - Disconnected from Redis
#
# 📊 RÉSUMÉ pour Tesla Inc:
#    ✅ Agents réussis: 2/3
#    🎯 Confiance moyenne: 0.40
#    ⏱️  Temps total: 0.011s
#
# ============================================================
# 📊 STATISTIQUES GLOBALES
#    🏢 Entreprises testées: 3
#    ✅ Entreprises avec succès: 3
#    🎯 Confiance moyenne globale: 0.55
#    ⏱️  Temps moyen par entreprise: 0.018s
#    ⏱️  Temps total: 0.203s
#
# 📋 Résultat final: {
#   "total_companies": 3,
#   "successful_companies": 3,
#   "average_confidence": 0.5499999999999999,
#   "average_time_per_company": 0.017679929733276367,
#   "total_time": 0.20291638374328613
# }
#
#
# ----------------------------------------
# 3️⃣ Test workflow complet via orchestrateur:
# 🎯 Test orchestrateur pour : Amazon Inc
# ✅ Test réussi
# 🎯 Test workflow orchestrateur pour : Amazon Inc
# --------------------------------------------------
# 15:40:57 | INFO     | orchestrator.logging_config:__init__:33 - LoggingManager initialized
# 15:40:57 | INFO     | orchestrator.core:__init__:122 - OrchestrationEngine initialized
# 15:40:57 | INFO     | orchestrator.core:execute_session:139 - Starting exploration session
# 15:40:57 | INFO     | orchestrator.core:execute_session:160 - Session initialized successfully
# ✅ Workflow terminé en 0.001s
# 📊 Session ID: 7a399364-2e31-4ada-9b1f-e36c6ac188bc
# 📊 Statut: initialized
#
# 📋 Résultat final: {
#   "success": true,
#   "company": "Amazon Inc",
#   "execution_time": 0.0013527870178222656,
#   "result": {
#     "session_id": "7a399364-2e31-4ada-9b1f-e36c6ac188bc",
#     "enterprise_name": "Amazon Inc",
#     "status": "initialized",
#     "message": "Session created successfully",
#     "execution_time": 0.0006554126739501953
#   }
# }
#
#
# ----------------------------------------
# 4️⃣ Test de performance du cache:
# ❌ Test échoué
# 2025-06-27 15:40:58.454 | INFO     | orchestrator.model_router:__init__:19 - ModelRouter initialized
# 2025-06-27 15:40:58.455 | INFO     | orchestrator.queue_manager:__init__:19 - SimpleQueueManager initialized
# Traceback (most recent call last):
#   File "/app/test_scripts/test_interactive.py", line 317, in <module>
#     main()
#     ^^^^^^
#   File "/app/test_scripts/test_interactive.py", line 308, in main
#     result = asyncio.run(test_cache_performance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/base_events.py", line 654, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/app/test_scripts/test_interactive.py", line 243, in test_cache_performance
#     await cache_manager.invalidate_category("performance")
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'CacheManager' object has no attribute 'invalidate_category'. Did you mean: 'invalidate_pattern'?
#
#
# ============================================================
# 🎮 FIN DES TESTS INTERACTIFS
# ============================================================

# %%
# 4. Test performance cache
print("4️⃣ Test de performance du cache:")
cache_result = run_test_script_with_args('test_interactive.py', 'cache')

if cache_result['success']:
    print("✅ Test réussi")
    print(cache_result['stdout'])
else:
    print("❌ Test échoué")
    print(cache_result['stderr'])

print("\n" + "=" * 60)
print("🎮 FIN DES TESTS INTERACTIFS")
print("=" * 60)
# Out:
# 4️⃣ Test de performance du cache:
# ❌ Test échoué
# 2025-06-27 15:40:59.460 | INFO     | orchestrator.model_router:__init__:19 - ModelRouter initialized
# 2025-06-27 15:40:59.461 | INFO     | orchestrator.queue_manager:__init__:19 - SimpleQueueManager initialized
# Traceback (most recent call last):
#   File "/app/test_scripts/test_interactive.py", line 317, in <module>
#     main()
#     ^^^^^^
#   File "/app/test_scripts/test_interactive.py", line 308, in main
#     result = asyncio.run(test_cache_performance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/asyncio/base_events.py", line 654, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/app/test_scripts/test_interactive.py", line 243, in test_cache_performance
#     await cache_manager.invalidate_category("performance")
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'CacheManager' object has no attribute 'invalidate_category'. Did you mean: 'invalidate_pattern'?
#
#
# ============================================================
# 🎮 FIN DES TESTS INTERACTIFS
# ============================================================
